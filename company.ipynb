# %% [markdown]
# <a href="https://colab.research.google.com/github/syedbaqir12/HR-DISTRIBUTION-REPORT/blob/main/company.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path='/content/drive/MyDrive/company/Companies.csv'
df = pd.read_csv(path)
df.head(6912)
# Out:
#       Year     Emirate_EN  Emirate_AR       City_EN     City_AR  LONGITUDE  \
# 0     2016       Fujairah     الفجيرة      Fujiarah     الفجيرة  56.261760
# 1     2016      Abu Dhabi     أبو ظبي         Delma        دلما  54.366669
# 2     2016      Abu Dhabi     أبو ظبي         Delma        دلما  54.366669
# 3     2016      Abu Dhabi     أبو ظبي         Delma        دلما  54.366669
# 4     2016      Abu Dhabi     أبو ظبي        Al-Ain       العين  54.366669
# ...    ...            ...         ...           ...         ...        ...
# 6906  2013  Um Al Qaiwain  أم القيوين   Om-El-Quain  أم القيوين  55.713391
# 6907  2014      Abu Dhabi     أبو ظبي  Madina Zayed  مدينة زايد  54.366669
# 6908  2011          Dubai         دبى         Dubai         دبى  55.296249
# 6909  2011        Sharjah     الشارقة        Kalbaa       كلباء  55.513641
# 6910  2012      Abu Dhabi     أبو ظبي  Madina Zayed  مدينة زايد  54.366669
#
#        LATITUDE                            Activity_EN  \
# ...

# %%
df.dropna(inplace=True)

# %%
df.drop(['Emirate_AR'], axis=1, inplace=True)
df.drop(['City_AR'], axis=1, inplace=True)
df.drop(['Activity_AR'], axis=1, inplace=True)
df.drop(['Est_size_AR'], axis=1, inplace=True)
df.head(6912)
# Out:
#       Year     Emirate_EN       City_EN  LONGITUDE   LATITUDE  \
# 0     2016       Fujairah      Fujiarah  56.261760  25.592460
# 1     2016      Abu Dhabi         Delma  54.366669  24.466667
# 2     2016      Abu Dhabi         Delma  54.366669  24.466667
# 3     2016      Abu Dhabi         Delma  54.366669  24.466667
# 4     2016      Abu Dhabi        Al-Ain  54.366669  24.466667
# ...    ...            ...           ...        ...        ...
# 6906  2013  Um Al Qaiwain   Om-El-Quain  55.713391  25.520482
# 6907  2014      Abu Dhabi  Madina Zayed  54.366669  24.466667
# 6908  2011          Dubai         Dubai  55.296249  25.276987
# 6909  2011        Sharjah        Kalbaa  55.513641  25.322327
# 6910  2012      Abu Dhabi  Madina Zayed  54.366669  24.466667
#
#                                 Activity_EN Est_size_EN  Est_MOHRE_Count
# 0     Transport, storage and communications  [250, 499]                5
# 1                             Manufacturing          <9                7
# ...

# %%
df.rename(columns={'Emirate_EN': 'EMIRATE'}, inplace=True)
df.rename(columns={'City_EN': 'CITY'}, inplace=True)
df.rename(columns={'Activity_EN': 'ACTIVITY'}, inplace=True)
df.rename(columns={'Est_size_EN': 'ESt_SIZE'}, inplace=True)
df.rename(columns={'Est_MOHRE_Count': 'EST_COUNT'}, inplace=True)
df.head(6912)
# Out:
#       Year        EMIRATE          CITY  LONGITUDE   LATITUDE  \
# 0     2016       Fujairah      Fujiarah  56.261760  25.592460
# 1     2016      Abu Dhabi         Delma  54.366669  24.466667
# 2     2016      Abu Dhabi         Delma  54.366669  24.466667
# 3     2016      Abu Dhabi         Delma  54.366669  24.466667
# 4     2016      Abu Dhabi        Al-Ain  54.366669  24.466667
# ...    ...            ...           ...        ...        ...
# 6906  2013  Um Al Qaiwain   Om-El-Quain  55.713391  25.520482
# 6907  2014      Abu Dhabi  Madina Zayed  54.366669  24.466667
# 6908  2011          Dubai         Dubai  55.296249  25.276987
# 6909  2011        Sharjah        Kalbaa  55.513641  25.322327
# 6910  2012      Abu Dhabi  Madina Zayed  54.366669  24.466667
#
#                                    ACTIVITY    ESt_SIZE  EST_COUNT
# 0     Transport, storage and communications  [250, 499]          5
# 1                             Manufacturing          <9          7
# ...

# %%
from matplotlib import pyplot as plt
_df_8.plot(kind='scatter', x='Year', y='EST_COUNT', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_4.groupby('EMIRATE').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['Year'].plot(kind='hist', bins=20, title='Year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data = {
    'Year': [2016, 2016, 2016, 2016, 2016],
    'EMIRATE': ['Fujairah', 'Abu Dhabi', 'Abu Dhabi', 'Abu Dhabi', 'Abu Dhabi'],

    'CITY': ['Fujiarah', 'Delma', 'Delma', 'Delma', 'Al-Ain'],

    'LONGITUDE': [56.26176, 54.366669, 54.366669, 54.366669, 54.366669],
    'LATITUDE': [25.59246, 24.466667, 24.466667, 24.466667, 24.466667],
    'ACTIVITY': [
        'Transport, storage and communications',
        'Manufacturing',
        'Social and personal services',
        'Transport, storage and communications',
        'Education'],
    'EST_SIZE': ['[250, 499]', '<9', '<9', '[10,19]', '[10,19]'],
    'EST_COUNT': [5, 7, 6, 1, 20]
}

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Total number of rows
total_rows = len(df)

# Display the first few rows (sample)
sample_rows = df.head()

# Column descriptions
column_descriptions = {
    'Year': 'The year in which the data was recorded',
    'EMIRATE': 'Emirate name in English',
    'CITY': 'City name in English',
    'LONGITUDE': 'Longitude coordinates',
    'LATITUDE': 'Latitude coordinates',
    'ACTIVITY': 'Economic activity in English',
    'EST_SIZE': 'Estimated size of establishments in English',
    'EST_COUNT': 'Estimated MOHRE (Ministry of Human Resources and Emiratisation) count',
}

# Print the results
print("Total Rows:", total_rows)
print("\nSample Rows:")
print(sample_rows)
print("\nColumn Descriptions:")
for col, description in column_descriptions.items():
    print(f"{col}: {description}")
# Out:
# Total Rows: 5
#
# Sample Rows:
#    Year    EMIRATE      CITY  LONGITUDE   LATITUDE  \
# 0  2016   Fujairah  Fujiarah  56.261760  25.592460
# 1  2016  Abu Dhabi     Delma  54.366669  24.466667
# 2  2016  Abu Dhabi     Delma  54.366669  24.466667
# 3  2016  Abu Dhabi     Delma  54.366669  24.466667
# 4  2016  Abu Dhabi    Al-Ain  54.366669  24.466667
#
#                                 ACTIVITY    EST_SIZE  EST_COUNT
# 0  Transport, storage and communications  [250, 499]          5
# 1                          Manufacturing          <9          7
# 2           Social and personal services          <9          6
# 3  Transport, storage and communications     [10,19]          1
# 4                              Education     [10,19]         20
#
# Column Descriptions:
# Year: The year in which the data was recorded
# EMIRATE: Emirate name in English
# CITY: City name in English
# LONGITUDE: Longitude coordinates
# LATITUDE: Latitude coordinates
# ACTIVITY: Economic activity in English
# ...
